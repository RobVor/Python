# %%
import pandas

DataFrame = pandas.DataFrame([[2,4,6],[10,20,30]],index=["First","Second"],columns=["Price", "Age", "Value"])
print(DataFrame,"\n")

DataFrame2 = pandas.DataFrame([{"Name":"Rob","Surname":"Vor"},{"Name":"Jack","Surname":"Longe"},{"Name":"Desmond"}])
print(DataFrame2,"\n")
DataFrame.mean()

DataFrame3 = pandas.read_csv("C:\\Users\\rvorster\\Downloads\\GI_processed.csv")
DataFrame3
# Out:
#         Price  Age  Value
# First       2    4      6
# Second     10   20     30
#
#       Name Surname
# 0      Rob     Vor
# 1     Jack   Longe
# 2  Desmond     NaN
#         Status          Contract Type Gender  Age Alternative Contact  \
# 0            0   Straight Up 50 TopUp      M   34                 Yes
# 1            0     Pinnacle 100 TopUp      F   45                 Yes
# 2            0         Epic 100 TopUp      F   24                 Yes
# 3            0     Pinnacle 150 TopUp      M   41                 Yes
# 4            0      Pinnacle 50 TopUp      F   30                 Yes
# 5            0         Epic 100 TopUp      M   22                 Yes
# 6            0     Pinnacle 150 TopUp      M   50                 Yes
# 7            0     Pinnacle 100 TopUp      F   27                 Yes
# 8            0      Pinnacle 50 TopUp      F   37                 Yes
# 9            0     Pinnacle 100 TopUp      M   56                 Yes
# ...

# %%
DataFrame4 = pandas.read_csv("http://pythonhow.com/supermarkets.csv", index_col="ID")
DataFrame4
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
DataFrame4.loc[2:4,"Name":"Employees"]
# Out:
#            Name  Employees
# ID
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10

# %%
DataFrame4.iloc[0:3,1:3]
# Out:
#              City             State
# ID
# 1   San Francisco          CA 94114
# 2   San Francisco          CA 94119
# 3   San Francisco  California 94114

# %%
DataFrame4.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='ID')

# %%
DataFrame4.columns
# Out:
# Index(['Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
DataFrame4["Continent"]=["North America"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-3c9b2b18fbef> in <module>()
# ----> 1 DataFrame4["Continent"]=["North America"]
#
# c:\users\rvorster\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# c:\users\rvorster\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ...

# %%
DataFrame4["Continent"]=DataFrame4.shape[0]*["North America"]
DataFrame4
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
DataFrame4["Continent"]=DataFrame4["Country"] + ", North America"
DataFrame4
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees           Continent
# ID
# 1           8  USA, North America
# 2          15  USA, North America
# 3          25  USA, North America
# 4          10  USA, North America
# 5          12  USA, North America
# 6          20  USA, North America

# %%
DataFrame4_Transpose = DataFrame4.T
DataFrame4_Transpose
# Out:
# ID                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...
